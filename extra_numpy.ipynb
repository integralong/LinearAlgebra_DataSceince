# %% [markdown]
# # Extra of NumPy

# %% [markdown]
# To understand what is the NumPy in python

# %%
import numpy as np

arr = np.array([1,2,3,4,5])
print(arr)
# Out:
# [1 2 3 4 5]

# %%
print(np.__version__)
# Out:
# 2.2.6

# %%
# create a numpy ndarray object

print(type(arr))
# Out:
# <class 'numpy.ndarray'>

# %%
# use a tuple to create a numpy array 

arr1 = np.array((1,2,3,4,5,6))
print(arr1)
# Out:
# [1 2 3 4 5 6]

# %%
print(type(arr1))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# > dimensions in arrays: a dimension in ararys is one level of array depth (nested arrays)

# %% [markdown]
# ### O-D Arrays
#
# 0-D arrays, or Scalars, are the elements in an array. each value in an array is a 0-D array

# %%
# create a 0-D array with value 42

import numpy as np
arr = np.array(42)
print(arr)
# Out:
# 42

# %% [markdown]
# ### 1-D Arrays
#
# an array that has 0-D arrays as its elements is called uni-dimensional or 1-D array

# %%
# create a 1-D array containing the values 1,2,3,4,5:

import numpy as np
arr = np.array([1,2,3,4,5])
print(arr)
# Out:
# [1 2 3 4 5]

# %% [markdown]
# ### 2-D Arrays
# an array that has 1-D arrays as its elements is called a 2-D array
#
# these are often used to represent matrix or 2nd order tensors
#
# * NumPy has a whole sub module dedicated towards matrix operations called numpy.mat

# %%
#Create a 2-D array containing two arrays with the values 1,2,3 and 4,5,6:
import numpy as np

arr = np.array([[1,2,3], [4,5,6]])
print(arr)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %% [markdown]
# ### 3-D Arrays
#
# an array that has 2-D arrays (matrices) as its elements is called 3-D array
#
# these are often used to represent a 3rd order tensor

# %%
# create a 3-D array with two 2-D arrays, both containing two arrays with the values 1,2,3
# and 4,5,6:

import numpy as np
arr = np.array([[[1,2,3], [4,5,6]], [[1,2,3], [4,5,6]]])
print((arr))
# Out:
# [[[1 2 3]
#   [4 5 6]]
#
#  [[1 2 3]
#   [4 5 6]]]

# %%
import numpy as np

a = np.array(42)
b = np.array([1, 2, 3, 4, 5])
c = np.array([[1, 2, 3], [4, 5, 6]])
d = np.array([[[1, 2, 3], [4, 5, 6]], [[1, 2, 3], [4, 5, 6]]])

print(a.ndim)
print(b.ndim)
print(c.ndim)
print(d.ndim)
# Out:
# 0
# 1
# 2
# 3

# %%
import numpy as np

arr = np.array([1, 2, 3, 4], ndmin=5)

print(arr)
print('number of dimensions :', arr.ndim)
# Out:
# [[[[[1 2 3 4]]]]]
# number of dimensions : 5

# %% [markdown]
# ### data types in numpy
#
# numpy has some extra data types, and refer to data types with one character, like i for integers, u for unsinged integers etc.

# %%
import numpy as np
arr = np.array(['apple', 'banana', 'cherry'])
print(arr.dtype)
# Out:
# <U6
